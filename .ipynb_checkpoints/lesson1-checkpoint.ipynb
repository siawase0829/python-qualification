# %%
print("hello world")
# Out:
# hello world

# %%
for i in range(10):
    print(f"hello world {i=:<05}")
# Out:
# hello world i=00000
# hello world i=10000
# hello world i=20000
# hello world i=30000
# hello world i=40000
# hello world i=50000
# hello world i=60000
# hello world i=70000
# hello world i=80000
# hello world i=90000

# %%
[ i for i in range(10) if i % 2 == 0]
# Out:
# [0, 2, 4, 6, 8]

# %%
import matplotlib
import requests

# %%
import pandas
class Test():
    def hello(self):
        print("hello world")
hello()

# %%
import scilab2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import scilab2
#
# ModuleNotFoundError: No module named 'scilab2'

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# データを用意
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

# グラフを描画
plt.plot(x, y)

# グラフのタイトルとラベルを設定
plt.title("Sample Plot")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")

# グラフを表示
plt.show()

# %%
import curses

def main(stdscr):
    # 端末の設定
    curses.curs_set(0)  # カーソルを非表示にする
    stdscr.nodelay(1)   # ノンブロッキングモードにする
    stdscr.timeout(100) # 100msごとにタイムアウト

    # 初期位置
    sh, sw = stdscr.getmaxyx()
    w = curses.newwin(sh, sw, 0, 0)
    turtle = '^'
    x, y = sh // 2, sw // 2

    # キー入力用の辞書
    key = curses.KEY_RIGHT

    while True:
        next_key = w.getch()
        key = key if next_key == -1 else next_key

        if key == ord('q'):
            break

        # 現在の亀の位置を消す
        w.clear()

        # 移動方向を決定
        if key == curses.KEY_UP:
            turtle = '^'
            x -= 1
        elif key == curses.KEY_DOWN:
            turtle = 'v'
            x += 1
        elif key == curses.KEY_LEFT:
            turtle = '<'
            y -= 1
        elif key == curses.KEY_RIGHT:
            turtle = '>'
            y += 1

        # 亀が端を越えないようにする
        x = max(0, min(x, sh - 1))
        y = max(0, min(y, sw - 1))

        # 新しい亀の位置を表示
        w.addch(x, y, turtle)
        w.refresh()

curses.wrapper(main)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import curses
#       3 def main(stdscr):
#       4     # 端末の設定
#       5     curses.curs_set(0)  # カーソルを非表示にする
#
# File /private/var/containers/Bundle/Application/9473DC42-1F54-4BED-8019-BCFFDB02EB58/Carnets.app/Library/lib/python3.11/curses/__init__.py:13
#       1 """curses
#       2
#       3 The main package for curses support for Python.  Normally used by importing
#    (...)
#      10
#      11 """
# ---> 13 from _curses import *
#      14 import os as _os
#      15 import sys as _sys
#
# ModuleNotFoundError: No module named '_curses'

# %%
import math
print(math.sin(math.pi))

class Test:
    def __init__(self,name):
        self.name=name
        
    def hello(self):
        print("hello world {se")

t1=Test("kouji")
t1.hello()
# Out:
# 1.2246467991473532e-16
# hello world

# %%
def func():
    print("hello")
    
class Test():
    def hello(self):
        print("class hello world")

func.test = Test()


func()
func.test.hello()
# Out:
# hello
# class hello world

# %%
import abc
dir(abc)
# Out:
# ['ABC',
#  'ABCMeta',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_abc_init',
#  '_abc_instancecheck',
#  '_abc_register',
#  '_abc_subclasscheck',
#  '_get_dump',
#  '_reset_caches',
#  '_reset_registry',
#  'abstractclassmethod',
#  'abstractmethod',
#  'abstractproperty',
#  'abstractstaticmethod',
#  'get_cache_token',
#  'update_abstractmethods']

# %%
(lambda x,y: x**y)(2,3)
# Out:
# 8

# %%
import pandas as pd
import matplotlib.pyplot as plt

# データフレーム生成
data = {'a': [1, 2, 3], 'b': [4, 5, 6]}
df = pd.DataFrame(data)

# プロット
df.plot(kind='bar')
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# データ生成
x = np.linspace(-5, 5, 100)
y = np.sin(x)
z = np.cos(x)

# 3Dグラフ作成
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 3D線グラフをプロット
ax.plot(x, y, z)

# ラベル設定
ax.set_xlabel('X軸')
ax.set_ylabel('Y軸')
ax.set_zlabel('Z軸')

plt.show()
# Out:
# /private/var/containers/Bundle/Application/9473DC42-1F54-4BED-8019-BCFFDB02EB58/Carnets.app/Library/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 36600 (\N{CJK UNIFIED IDEOGRAPH-8EF8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# データ生成
x = np.random.rand(100)
y = np.random.rand(100)
z = np.random.rand(100)

# 3Dグラフ作成
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 3D散布図をプロット
ax.scatter(x, y, z)

# ラベル設定
ax.set_xlabel('X軸')
ax.set_ylabel('Y軸')
ax.set_zlabel('Z軸')

plt.show()

# %%
# データ生成
x = np.arange(1, 11)
y = np.random.randint(1, 10, 10)
z = np.zeros(10)

# 3Dグラフ作成
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 3D棒グラフをプロット
ax.bar(x, y, z)

# ラベル設定
ax.set_xlabel('X軸')
ax.set_ylabel('Y軸')
ax.set_zlabel('Z軸')
ax.view_init(elev=30, azim=60)  # 高さ30度、方位60度からの視点
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

# データ生成
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = np.sin(np.sqrt(x**2 + y**2))

# 3Dグラフ作成
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 3Dサーフェスプロットを作成
ax.plot_surface(x, y, z, cmap='viridis')

# ラベル設定
ax.set_xlabel('X軸')
ax.set_ylabel('Y軸')
ax.set_zlabel('Z軸')

plt.show()

# %%
# Jupyter Notebookでインタラクティブモ


import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# データ生成
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = np.sin(np.sqrt(x**2 + y**2))

# 3Dグラフ作成
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 3Dサーフェスプロットを作成
ax.plot_surface(x, y, z, cmap='viridis')

# インタラクティブに視点を変更可能
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import time

# データ生成
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = np.sin(np.sqrt(x**2 + y**2))

# 3Dグラフ作成
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 3Dサーフェスプロットを作成
ax.plot_surface(x, y, z, cmap='viridis')

# 角度を変えて表示する
for angle in range(0, 360, 10):
    ax.view_init(elev=30, azim=angle)
    plt.draw()
    time.sleep(0.5)

# %%
# !pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting plotly
#   Downloading plotly-5.24.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting tenacity>=6.2.0 (from plotly)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: packaging in /private/var/containers/Bundle/Application/9473DC42-1F54-4BED-8019-BCFFDB02EB58/Carnets.app/Library/lib/python3.11/site-packages (from plotly) (23.2)
# Downloading plotly-5.24.0-py3-none-any.whl (19.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.0/19.0 MB 1.8 MB/s eta 0:00:00
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.24.0 tenacity-9.0.0
# [notice] A new release of pip is available: 23.3.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import plotly.express as px

# サンプルデータをロード
df = px.data.iris()

# 散布図を作成
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species", title="Iris Data Scatter Plot")

# グラフを表示
fig.show()
# Out:
# <div>                            <div id="03da436b-192b-464f-9363-43c2005d7902" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03da436b-192b-464f-9363-43c2005d7902")) {                    Plotly.newPlot(                        "03da436b-192b-464f-9363-43c2005d7902",                        [{"hovertemplate":"species=setosa\u003cbr\u003esepal_width=%{x}\u003cbr\u003esepal_length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"setosa","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"setosa","orientation":"v","showlegend":true,"x":[3.5,3.0,3.2,3.1,3.6,3.9,3.4,3.4,2.9,3.1,3.7,3.4,3.0,3.0,4.0,4.4,3.9,3.5,3.8,3.8,3.4,3.7,3.6,3.3,3.4,3.0,3.4,3.5,3.4,3.2,3.1,3.4,4.1,4.2,3.1,3.2,3.5,3.1,3.0,3.4,3.5,2.3,3.2,3.5,3.8,3.0,3.8,3.2,3.7,3.3],"xaxis":"x","y":[5.1,4.9,4.7,4.6,5.0,5.4,4.6,5.0,4.4,4.9,5.4,4.8,4.8,4.3,5.8,5.7,5.4,5.1,5.7,5.1,5.4,5.1,4.6,5.1,4.8,5.0,5.0,5.2,5.2,4.7,4.8,5.4,5.2,5.5,4.9,5.0,5.5,4.9,4.4,5.1,5.0,4.5,4.4,5.0,5.1,4.8,5.1,4.6,5.3,5.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"species=versicolor\u003cbr\u003esepal_width=%{x}\u003cbr\u003esepal_length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"versicolor","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"versicolor","orientation":"v","showlegend":true,"x":[3.2,3.2,3.1,2.3,2.8,2.8,3.3,2.4,2.9,2.7,2.0,3.0,2.2,2.9,2.9,3.1,3.0,2.7,2.2,2.5,3.2,2.8,2.5,2.8,2.9,3.0,2.8,3.0,2.9,2.6,2.4,2.4,2.7,2.7,3.0,3.4,3.1,2.3,3.0,2.5,2.6,3.0,2.6,2.3,2.7,3.0,2.9,2.9,2.5,2.8],"xaxis":"x","y":[7.0,6.4,6.9,5.5,6.5,5.7,6.3,4.9,6.6,5.2,5.0,5.9,6.0,6.1,5.6,6.7,5.6,5.8,6.2,5.6,5.9,6.1,6.3,6.1,6.4,6.6,6.8,6.7,6.0,5.7,5.5,5.5,5.8,6.0,5.4,6.0,6.7,6.3,5.6,5.5,5.5,6.1,5.8,5.0,5.6,5.7,5.7,6.2,5.1,5.7],"yaxis":"y","type":"scatter"},{"hovertemplate":"species=virginica\u003cbr\u003esepal_width=%{x}\u003cbr\u003esepal_length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"virginica","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"virginica","orientation":"v","showlegend":true,"x":[3.3,2.7,3.0,2.9,3.0,3.0,2.5,2.9,2.5,3.6,3.2,2.7,3.0,2.5,2.8,3.2,3.0,3.8,2.6,2.2,3.2,2.8,2.8,2.7,3.3,3.2,2.8,3.0,2.8,3.0,2.8,3.8,2.8,2.8,2.6,3.0,3.4,3.1,3.0,3.1,3.1,3.1,2.7,3.2,3.3,3.0,2.5,3.0,3.4,3.0],"xaxis":"x","y":[6.3,5.8,7.1,6.3,6.5,7.6,4.9,7.3,6.7,7.2,6.5,6.4,6.8,5.7,5.8,6.4,6.5,7.7,7.7,6.0,6.9,5.6,7.7,6.3,6.7,7.2,6.2,6.1,6.4,7.2,7.4,7.9,6.4,6.3,6.1,7.7,6.3,6.4,6.0,6.9,6.7,6.9,5.8,6.8,6.7,6.7,6.3,6.5,6.2,5.9],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapg ...

# %%
import seaborn as sns
print(sns.get_dataset_names())
df=sns.load_dataset('iris')
print(df)
sns.
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 5
#       3 df=sns.load_dataset('iris')
#       4 print(df)
# ----> 5 sns.heatmap(df)
#
# File /var/mobile/Containers/Data/Application/36D27172-ABFA-4B59-B04D-5232107930E0/Library/lib/python3.11/site-packages/seaborn/matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
#     451 kwargs["linewidths"] = linewidths
#
# File /var/mobile/Containers/Data/Application/36D27172-ABFA-4B59-B04D-5232107930E0/Library/lib/python3.11/site-packages/seaborn/matrix.py:163, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     160 self.ylabel = ylabel if ylabel is not None else ""
#     162 # Determine good default values for the colormapping
# --> 163 self._determine_cmap_params(plot_data, vmin, vmax,
#     164                             cmap, center, robust)
#     166 # Sort out the annotations
#     167 if annot is None or annot is False:
#
# File /var/mobile/Containers/Data/Application/36D27172-ABFA-4B59-B04D-5232107930E0/Library/lib/python3.11/site-packages/seaborn/matrix.py:197, in _HeatMapper._determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     194 """Use some heuristics to set good defaults for colorbar and range."""
#     196 # plot_data is a np.ma.array instance
# --> 197 calc_data = plot_data.astype(float).filled(np.nan)
#     198 if vmin is None:
#     199     if robust:
#
# ValueError: could not convert string to float: 'setosa'

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /private/var/containers/Bundle/Application/9473DC42-1F54-4BED-8019-BCFFDB02EB58/Carnets.app/Library/lib/python3.11/site-packages (from seaborn) (1.25.2+2.g530bd4c06)
# Requirement already satisfied: pandas>=1.2 in /private/var/containers/Bundle/Application/9473DC42-1F54-4BED-8019-BCFFDB02EB58/Carnets.app/Library/lib/python3.11/site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /private/var/containers/Bundle/Application/9473DC42-1F54-4BED-8019-BCFFDB02EB58/Carnets.app/Library/lib/python3.11/site-packages (from seaborn) (3.9.0.dev16+g5446a454e4)
# Requirement already satisfied: contourpy>=1.0.1 in /private/var/containers/Bundle/Application/9473DC42-1F54-4BED-8019-BCFFDB02EB58/Carnets.app/Library/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /private/var/containers/Bundle/Application/9473DC42-1F54-4BED-8019-BCFFDB02EB58/Carnets.app/Library/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /private/var/containers/Bundle/Application/9473DC42-1F54-4BED-8019-BCFFDB02EB58/Carnets.app/Library/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /private/var/containers/Bundle/Application/9473DC42-1F54-4BED-8019-BCFFDB02EB58/Carnets.app/Library/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /private/var/containers/Bundle/Application/9473DC42-1F54-4BED-8019-BCFFDB02EB58/Carnets.app/Library/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /private/var/containers/Bundle/Application/9473DC42-1F54-4BED-8019-BCFFDB02EB58/Carnets.app/Library/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /private/var/containers/Bundle/Application/9473DC42-1F54-4BED-8019-BCFFDB02EB58/Carnets.app/Library/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /private/var/containers/Bundle/Application/9473DC42-1F54-4BED-8019-BCFFDB02EB58/Carnets.app/Library/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: setuptools-scm>=7 in /private/var/containers/Bundle/Application/9473DC42-1F54-4BED-8019-BCFFDB02EB58/Carnets.app/Library/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (8.0.4)
# Requirement already satisfied: pytz>=2020.1 in /private/var/containers/Bundle/Application/9473DC42-1F54-4BED-8019-BCFFDB02EB58/Carnets.app/Library/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /private/var/containers/Bundle/Application/9473DC42-1F54-4BED-8019-BCFFDB02EB58/Carnets.app/Library/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: six>=1.5 in /private/var/containers/Bundle/Application/9473DC42-1F54-4BED-8019-BCFFDB02EB58/Carnets.app/Library/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: setuptools in /private/var/containers/Bundle/Application/9473DC42-1F54-4BED-8019-BCFFDB02EB58/Carnets.app/Library/lib/python3.11/site-packages (from setuptools-scm>=7->matplotlib!=3.6.1,>=3.4->seaborn) (69.0.3)
# Requirement already satisfied: typing-extensions in /private/var/containers/Bundle/Application/9473DC42-1F54-4BED-8019-BCFFDB02EB58/Carnets.app/Library/lib/python3.11/site-packages (from setuptools-scm>=7->matplotlib!=3.6.1,>=3.4->seaborn) (4.9.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 562.9 kB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# [notice] A new release of pip is available: 23.3.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import plotly.express as px
import plotly.io as pio

# デフォルトの出力方法をブラウザに設定
pio.renderers.default = "browser"

# サンプルデータを使用してグラフを作成
df = px.data.iris()  # アイリスデータセットを使用

# Plotly Expressで散布図を作成
fig = px.scatter(df, x='sepal_width', y='sepal_length', color='species',
                 title="Iris Sepal Dimensions")

# グラフを表示
fig.show()

# %%
import plotly.express as px
import plotly.io as pio

# Jupyter Notebook内にグラフを表示する設定
pio.renderers.default = "notebook_connected"

# サンプルデータを使用して3D散布図を作成
df = px.data.iris()

# 3D散布図を作成
fig = px.scatter_3d(df, x='sepal_length', y='sepal_width', z='petal_length', 
                    color='species', title="3D Scatter Plot of Iris Dataset")

# グラフを表示
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="507159ca-3439-4481-aa6d-08605ad0c92c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("507159ca-3439-4481-aa6d-08605ad0c92c")) {                    Plotly.newPlot(                        "507159ca-3439-4481-aa6d-08605ad0c92c",                        [{"hovertemplate":"species=setosa\u003cbr\u003esepal_length=%{x}\u003cbr\u003esepal_width=%{y}\u003cbr\u003epetal_length=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"setosa","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"setosa","scene":"scene","showlegend":true,"x":[5.1,4.9,4.7,4.6,5.0,5.4,4.6,5.0,4.4,4.9,5.4,4.8,4.8,4.3,5.8,5.7,5.4,5.1,5.7,5.1,5.4,5.1,4.6,5.1,4.8,5.0,5.0,5.2,5.2,4.7,4.8,5.4,5.2,5.5,4.9,5.0,5.5,4.9,4.4,5.1,5.0,4.5,4.4,5.0,5.1,4.8,5.1,4.6,5.3,5.0],"y":[3.5,3.0,3.2,3.1,3.6,3.9,3.4,3.4,2.9,3.1,3.7,3.4,3.0,3.0,4.0,4.4,3.9,3.5,3.8,3.8,3.4,3.7,3.6,3.3,3.4,3.0,3.4,3.5,3.4,3.2,3.1,3.4,4.1,4.2,3.1,3.2,3.5,3.1,3.0,3.4,3.5,2.3,3.2,3.5,3.8,3.0,3.8,3.2,3.7,3.3],"z":[1.4,1.4,1.3,1.5,1.4,1.7,1.4,1.5,1.4,1.5,1.5,1.6,1.4,1.1,1.2,1.5,1.3,1.4,1.7,1.5,1.7,1.5,1.0,1.7,1.9,1.6,1.6,1.5,1.4,1.6,1.6,1.5,1.5,1.4,1.5,1.2,1.3,1.5,1.3,1.5,1.3,1.3,1.3,1.6,1.9,1.4,1.6,1.4,1.5,1.4],"type":"scatter3d"},{"hovertemplate":"species=versicolor\u003cbr\u003esepal_length=%{x}\u003cbr\u003esepal_width=%{y}\u003cbr\u003epetal_length=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"versicolor","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"versicolor","scene":"scene","showlegend":true,"x":[7.0,6.4,6.9,5.5,6.5,5.7,6.3,4.9,6.6,5.2,5.0,5.9,6.0,6.1,5.6,6.7,5.6,5.8,6.2,5.6,5.9,6.1,6.3,6.1,6.4,6.6,6.8,6.7,6.0,5.7,5.5,5.5,5.8,6.0,5.4,6.0,6.7,6.3,5.6,5.5,5.5,6.1,5.8,5.0,5.6,5.7,5.7,6.2,5.1,5.7],"y":[3.2,3.2,3.1,2.3,2.8,2.8,3.3,2.4,2.9,2.7,2.0,3.0,2.2,2.9,2.9,3.1,3.0,2.7,2.2,2.5,3.2,2.8,2.5,2.8,2.9,3.0,2.8,3.0,2.9,2.6,2.4,2.4,2.7,2.7,3.0,3.4,3.1,2.3,3.0,2.5,2.6,3.0,2.6,2.3,2.7,3.0,2.9,2.9,2.5,2.8],"z":[4.7,4.5,4.9,4.0,4.6,4.5,4.7,3.3,4.6,3.9,3.5,4.2,4.0,4.7,3.6,4.4,4.5,4.1,4.5,3.9,4.8,4.0,4.9,4.7,4.3,4.4,4.8,5.0,4.5,3.5,3.8,3.7,3.9,5.1,4.5,4.5,4.7,4.4,4.1,4.0,4.4,4.6,4.0,3.3,4.2,4.2,4.2,4.3,3.0,4.1],"type":"scatter3d"},{"hovertemplate":"species=virginica\u003cbr\u003esepal_length=%{x}\u003cbr\u003esepal_width=%{y}\u003cbr\u003epetal_length=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"virginica","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"virginica","scene":"scene","showlegend":true,"x":[6.3,5.8,7.1,6.3,6.5,7.6,4.9,7.3,6.7,7.2,6.5,6.4,6.8,5.7,5.8,6.4,6.5,7.7,7.7,6.0,6.9,5.6,7.7,6.3,6.7,7.2,6.2,6.1,6.4,7.2,7.4,7.9,6.4,6.3,6.1,7.7,6.3,6.4,6.0,6.9,6.7,6.9,5.8,6.8,6.7,6.7,6.3,6.5,6.2,5.9],"y":[3.3,2.7,3.0,2.9,3.0,3.0,2.5,2.9,2.5,3.6,3.2,2.7,3.0,2.5,2.8,3.2,3.0,3.8,2.6,2.2,3.2,2.8,2.8,2.7,3.3,3.2,2.8,3.0,2.8,3.0,2.8,3.8,2.8,2.8,2.6,3.0,3.4,3.1,3.0,3.1,3.1,3.1,2.7,3.2,3.3,3.0,2.5,3.0,3.4,3.0],"z":[6.0,5.1,5.9,5.6,5.8,6.6,4.5,6.3,5.8,6.1,5.1,5.3,5.5,5.0,5.1,5.3,5.5,6.7,6.9,5.0,5.7,4.9,6.7,4.9,5.7,6.0,4.8,4.9,5.6,5.8,6.1,6.4,5.6,5.1,5.6,6.1,5.6,5.5,4.8,5.4,5.6,5.1,5.1,5.9,5.7,5.2,5.0,5.2,5.4,5.1],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1 ...
